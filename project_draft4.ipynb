# %% [markdown]
# # <center>~ Exploration of US Flight Data ~</center>
# ## <center>A glimpse into flight data for Pittsburgh, PA in 1988 and 2007: With a focus on delays and the month of November</center>
# <p><em>Created by Miles Murphy</em></p>
# <em>October 31, 2020</em>

# %% [markdown]
# # Table of Contents:
# 1. [Introduction](#introduction)
#
# 2. [Project Background](#project_background)
#     1. [Data Source Information](#data_source_information)
# 3. [Data Wrangling](#data_wrangling)
#     1. [Data Details](#data_details)
#     2. [Data Tidiness](#data_tidiness)
#     3. [Data Quality](#data_quality)
# 4. [Data Exploration](#data_exploration)
#     1. [Univariate Exploration](#univariate_exploration)
#     2. [Bivariate Exploration](#bivariate_exploration)
#     3. [Multivariate Exploration](#multivariate_exploration)
# 5. [Project Conclusions and Results](#project_conclusions)

# %% [markdown]
# ## Introduction: <a name="introduction"></a>

# %% [markdown]
# The last 6 months of my life have been very productive while simultaneously mundane. Covid-19 turned society upside-down and the plan I was developing for my life took a 180-degree turn. Instead of being in a new public service role in a larger government, I find myself completing 6 months of 'night-school' classes related to Data Analysis. The last 6 months have shown me that I do not want to stay in government work, at least not in a front-facing role. Instead, I hope to find opportunities related to my interests and passions, data analysis/programming and environmental conservation respectively.
#
# I am telling you this, because this exploration of flight data for the year of 1988 and 2007 is my last project in my second Nanodegree and it will be submitted within weeks, if not days, of my 32nd birthday. I had no idea what I was going to do when I graduated highschool in 2007, let alone college in 2011, but I can assure you it did not involve me having even a remote understanding of Python, Git, SQL, and other programming languages. Yet, on a Halloween evening, I found myself sitting infront of my desktop building the outline of a project which may eventually open a door for a new job and an entirely new trajectory for my life. So, as I socially distance I will take you through flight data from the year 1988 and the year 2007(when I first left Pittsburgh), in honor of my impending birthday and the start this new adventure.

# %% [markdown]
# ## Project Background: <a name="project_background"></a>

# %% [markdown]
# ### Data Source Information: <a name="data_source_informationd"></a>

# %% [markdown]
# The data for this project comes from the larger ongoing database the Bureau of Transportation Statistics maintains related to Carrier On-Time Performance. The larger database features more details related to each flight, such as the reporting airline, airport location data, and other details. The database used in this project does not feature all of these details. Furthermore, the earlier the data is, the less complete the flight information. For instance, the 1988 dataframe does not feature any time information for 5 of the delay types the database features.

# %% [markdown]
# ## Data Wrangling <a name="data_wrangling"></a>

# %% [markdown]
# ### Data Details: <a name="data_details"></a>

# %%
#Import packages and set plots to be embedded
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import datetime as dt


#Credit to https://stackoverflow.com/questions/40105796/turn-warning-off-in-a-cell-jupyter-notebook
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %matplotlib inline

# %%
#load dataset into a pandas df
flights_88 = pd.read_csv('dataverse_files/1988.csv', dtype={'ArrTime': str, 'DepTime':str, 'CRSDepTime': str, 'CRSArrTime':str} )
flights_07 = pd.read_csv('dataverse_files/2007.csv', dtype={'ArrTime': str, 'DepTime':str, 'CRSDepTime': str, 'CRSArrTime':str})

# %% [markdown]
# #### What is the structure of the datasets?

# %%
#Exmaine basic df information
flights_88.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5202096 entries, 0 to 5202095
# Data columns (total 29 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Year               int64
#  1   Month              int64
#  2   DayofMonth         int64
#  3   DayOfWeek          int64
#  4   DepTime            object
#  5   CRSDepTime         object
#  6   ArrTime            object
#  7   CRSArrTime         object
#  8   UniqueCarrier      object
#  9   FlightNum          int64
#  10  TailNum            float64
#  11  ActualElapsedTime  float64
#  12  CRSElapsedTime     int64
#  13  AirTime            float64
#  14  ArrDelay           float64
#  15  DepDelay           float64
#  16  Origin             object
#  17  Dest               object
#  18  Distance           float64
#  19  TaxiIn             float64
#  20  TaxiOut            float64
#  21  Cancelled          int64
#  22  CancellationCode   float64
#  23  Diverted           int64
# ...

# %%
flights_07.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7453215 entries, 0 to 7453214
# Data columns (total 29 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Year               int64
#  1   Month              int64
#  2   DayofMonth         int64
#  3   DayOfWeek          int64
#  4   DepTime            object
#  5   CRSDepTime         object
#  6   ArrTime            object
#  7   CRSArrTime         object
#  8   UniqueCarrier      object
#  9   FlightNum          int64
#  10  TailNum            object
#  11  ActualElapsedTime  float64
#  12  CRSElapsedTime     float64
#  13  AirTime            float64
#  14  ArrDelay           float64
#  15  DepDelay           float64
#  16  Origin             object
#  17  Dest               object
#  18  Distance           int64
#  19  TaxiIn             int64
#  20  TaxiOut            int64
#  21  Cancelled          int64
#  22  CancellationCode   object
#  23  Diverted           int64
# ...

# %%
#Examine numerical data basic details
flights_88.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek     FlightNum  \
# count  5202096.0  5.202096e+06  5.202096e+06  5.202096e+06  5.202096e+06
# mean      1988.0  6.508971e+00  1.575754e+01  3.954361e+00  6.870138e+02
# std          0.0  3.445201e+00  8.798635e+00  1.987931e+00  5.186402e+02
# min       1988.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       1988.0  4.000000e+00  8.000000e+00  2.000000e+00  2.960000e+02
# 50%       1988.0  7.000000e+00  1.600000e+01  4.000000e+00  5.780000e+02
# 75%       1988.0  1.000000e+01  2.300000e+01  6.000000e+00  9.380000e+02
# max       1988.0  1.200000e+01  3.100000e+01  7.000000e+00  6.189000e+03
#
#        TailNum  ActualElapsedTime  CRSElapsedTime  AirTime      ArrDelay  ...  \
# count      0.0       5.137497e+06    5.202096e+06      0.0  5.137497e+06  ...
# mean       NaN       1.040407e+02    1.039866e+02      NaN  6.547350e+00  ...
# ...

# %%
flights_07.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek     FlightNum  \
# count  7453215.0  7.453215e+06  7.453215e+06  7.453215e+06  7.453215e+06
# mean      2007.0  6.514876e+00  1.572589e+01  3.933804e+00  2.188099e+03
# std          0.0  3.425117e+00  8.781154e+00  1.992267e+00  1.971958e+03
# min       2007.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2007.0  4.000000e+00  8.000000e+00  2.000000e+00  5.900000e+02
# 50%       2007.0  7.000000e+00  1.600000e+01  4.000000e+00  1.509000e+03
# 75%       2007.0  9.000000e+00  2.300000e+01  6.000000e+00  3.553000e+03
# max       2007.0  1.200000e+01  3.100000e+01  7.000000e+00  9.602000e+03
#
#        ActualElapsedTime  CRSElapsedTime       AirTime      ArrDelay  \
# count       7.275288e+06    7.452221e+06  7.275288e+06  7.275288e+06
# mean        1.263223e+02    1.272502e+02  1.028159e+02  1.019218e+01
# std         7.118009e+01    7.035750e+01  6.824577e+01  3.930774e+01
# ...

# %%
#Examine first 5 rows
flights_88.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek DepTime CRSDepTime ArrTime CRSArrTime  \
# 0  1988      1           9          6    1348       1331    1458       1435
# 1  1988      1          10          7    1334       1331    1443       1435
# 2  1988      1          11          1    1446       1331    1553       1435
# 3  1988      1          12          2    1334       1331    1438       1435
# 4  1988      1          13          3    1341       1331    1503       1435
#
#   UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  CancellationCode  \
# 0            PI        942  ...     NaN      NaN          0               NaN
# 1            PI        942  ...     NaN      NaN          0               NaN
# 2            PI        942  ...     NaN      NaN          0               NaN
# 3            PI        942  ...     NaN      NaN          0               NaN
# 4            PI        942  ...     NaN      NaN          0               NaN
#
# ...

# %%
flights_07.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek DepTime CRSDepTime ArrTime CRSArrTime  \
# 0  2007      1           1          1    1232       1225    1341       1340
# 1  2007      1           1          1    1918       1905    2043       2035
# 2  2007      1           1          1    2206       2130    2334       2300
# 3  2007      1           1          1    1230       1200    1356       1330
# 4  2007      1           1          1     831        830     957       1000
#
#   UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  CancellationCode  \
# 0            WN       2891  ...      4       11          0               NaN
# 1            WN        462  ...      5        6          0               NaN
# 2            WN       1229  ...      6        9          0               NaN
# 3            WN       1355  ...      3        8          0               NaN
# 4            WN       2278  ...      3        9          0               NaN
#
# ...

# %%
#Look for columns with a lot of NaNs
flights_88.isna().any()
# Out:
# Year                 False
# Month                False
# DayofMonth           False
# DayOfWeek            False
# DepTime               True
# CRSDepTime           False
# ArrTime               True
# CRSArrTime           False
# UniqueCarrier        False
# FlightNum            False
# TailNum               True
# ActualElapsedTime     True
# CRSElapsedTime       False
# AirTime               True
# ArrDelay              True
# DepDelay              True
# Origin               False
# Dest                 False
# Distance              True
# TaxiIn                True
# TaxiOut               True
# Cancelled            False
# CancellationCode      True
# Diverted             False
# CarrierDelay          True
# WeatherDelay          True
# NASDelay              True
# SecurityDelay         True
# LateAircraftDelay     True
# dtype: bool

# %%
flights_07.isna().any()
# Out:
# Year                 False
# Month                False
# DayofMonth           False
# DayOfWeek            False
# DepTime               True
# CRSDepTime           False
# ArrTime               True
# CRSArrTime           False
# UniqueCarrier        False
# FlightNum            False
# TailNum               True
# ActualElapsedTime     True
# CRSElapsedTime        True
# AirTime               True
# ArrDelay              True
# DepDelay              True
# Origin               False
# Dest                 False
# Distance             False
# TaxiIn               False
# TaxiOut              False
# Cancelled            False
# CancellationCode      True
# Diverted             False
# CarrierDelay         False
# WeatherDelay         False
# NASDelay             False
# SecurityDelay        False
# LateAircraftDelay    False
# dtype: bool

# %% [markdown]
# The two datasets contain data related to flight activity recorded in 1988 and 2007. There are 5202096 flights in the 1988 df and 7453215 flights in the 2007 df.

# %% [markdown]
# In honor of my place of birth and domecile for 20 of my nearly 32 years on Earth, this exploration will only focus on flight data related to Pittsburgh, PA. However, in addition to focusing on just flights related to Pittsburgh, there are other Data Tidiness and Data Quality issues which may need to be addressed to create more efficient dataframes for the intended visual exploration.

# %% [markdown]
# #### What are the main features of interest in the datasets?
#
# There are many interesting aspects of the flight data in both 88 and 07, but 7 main features of interest stand out in this dataset at this point:
# <ul>
#     <li>The most popular month for travel in 88 and 07 (November will be looked at due to it being my birth month and the overall theme of this visual data exploration</li>
#     <li>The most popular day of the week for travel in 88 and 07</li>
#     <li>The most popular origins for flights arriving in Pittsburgh</li>
#     <li>The most popular destinations for flights departing from Pittsburgh</li>
#     <li>The length of flights</li>
#     <li>The length of delays for flights that experience them (Delays will only be examined in 2007 as the 1988 data does not have the same information)</li>
#     <li>The most common type of delay</li>
# </ul>
#
# #### What features in the dataset will help support the investigation into the features of interest?
#
# The first five main features of interest (listed above) are easily examined utilizing the following columns:
# <ol>
#     <li>Month</li>
#     <li>DayOfWeek</li>
#     <li>Origin</li>
#     <li>Destination</li>
#     <li>ActualElapsedTime</li>
# </ol>
#
# However, the last two items are a little more difficult to handle. It may not be the most tidy method of organizing this data, but a secondary delays dataframe will be created with a categorical column which details the type of delay each flight experienced. The CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, and LateAircraftDelay columns feature delay time in minutes. These columns will be used for their literal delay data and compiled to create both a total delay column and a delay type column, as needed.
#
# #### Continuing the Theme
#
# Given the aforementioned timing related to the conclusion of this class and my 32nd birthday, an examination of the most popular date, day of the week, origin, and destination for flights in November of 1988 (and 2007) may also be examined as a part of the bivariate and multivariate exploration.
#
# Regardless, the next step will be to create a copy of the original dataframes, further examine the data, and begin any cleaning and reorganization of the data which is necessary.

# %%
#Create df copy for cleaning
flights_88_cleaning = flights_88.copy()
flights_07_cleaning = flights_07.copy()

# %% [markdown]
# ### Data Tidiness: <a name="data_tidiness"></a>

# %% [markdown]
# For Data Tidiness issues, this dataset is well organized already. Depending upon the analysis goals, the splitting of the date of each flight into four different pieces may not be efficient. The data could be combined into a date, a day of the week, and a time. However, if the data is being examined month to month, not having to use code to pull out the month of the date would be simpler.
#
# That being said, Data Tidiness issues will be handled as they develop from Data Quality cleaning steps, if any do develop.

# %% [markdown]
# ### Data Quality: <a name="data_quality"></a>

# %% [markdown]
# There are several data quality issues which need to be addressed. Some are inherent in the dataset and others are created during the required manipulation of data to suit this particular visual data exploration.

# %% [markdown]
# <ol>
#     <li>Only interested in flights originating or terminating in Pittsbrugh, PA</li>
#     <li>Arrival Time and Departure Time related columns should be datetime objects, not floats</li>
#     <li>Several NaN columns for the pgh_flights_88 df</li>
#     <li>Examine the delays outside of the larger 07 df</li>
#     <li>There is no categorial column for delays which would be useful in visualization of the data</li>
#     <li>There are a few extremely large delay times which greatly skew the delays df</li>
# </ol>

# %% [markdown]
# #### 1. Only interested in flights originating or terminating in Pittsburgh, PA

# %% [markdown]
# <em><b>Define</b></em>

# %% [markdown]
# Query the 1988 and 2007 dataframes to select only the flights which involve Pittsburgh, PA by using the 'Origin' and 'Dest' columns

# %% [markdown]
# <em><b>Code</b></em>

# %%
pgh_flights_88 = flights_88_cleaning.query("Dest == 'PIT' or Origin == 'PIT'")
pgh_flights_88.head()
# Out:
#        Year  Month  DayofMonth  DayOfWeek DepTime CRSDepTime ArrTime  \
# 15771  1988      1           1          5     657        701     810
# 15772  1988      1           2          6     659        701     754
# 15773  1988      1           3          7     701        701     750
# 15774  1988      1           4          1     701        701     824
# 15775  1988      1           5          2     659        701     749
#
#       CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# 15771        744            TW         73  ...     NaN      NaN          0
# 15772        744            TW         73  ...     NaN      NaN          0
# 15773        744            TW         73  ...     NaN      NaN          0
# 15774        744            TW         73  ...     NaN      NaN          0
# 15775        744            TW         73  ...     NaN      NaN          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
pgh_flights_07 = flights_07_cleaning.query("Dest == 'PIT' or Origin == 'PIT'")
pgh_flights_07.head()
# Out:
#       Year  Month  DayofMonth  DayOfWeek DepTime CRSDepTime ArrTime  \
# 194   2007      1           1          1    1034       1035    1232
# 1481  2007      1           2          2    1037       1035    1754
# 1482  2007      1           2          2    1504       1435    2219
# 1864  2007      1           2          2    1838       1830    2047
# 1865  2007      1           2          2    1322       1315    1525
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 194        1250            WN       2999  ...      5       11          0
# 1481       1745            WN        803  ...      4       15          0
# 1482       2140            WN       2659  ...      7        8          0
# 1864       2050            WN        491  ...      8       11          0
# 1865       1525            WN       1659  ...      6        9          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %% [markdown]
# <em><b>Test</b></em>

# %%
pgh_flights_88.query("Dest != 'PIT' and Origin != 'PIT'")
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 29 columns]

# %%
pgh_flights_07.query("Dest != 'PIT' and Origin != 'PIT'")
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# It needs to be noted here that of the original dataframes sizes, 5,202,096 flights in the 1988 df and 7,453,215 flights in the 2007 df, there were 237,901 flights involving Pittsburgh in 1988 and 98,419 flights involving Pittsburgh in 2007. In simple terms, there were more than double the flights going through Pittsburgh in 1988 than there were in 2007. There are many factors which contributed to this decline of over 50%, but they will not be discussed in much detail in this analysis, as it is not overly relevant.

# %% [markdown]
# #### 2. Arrival Time and Departure Time columns should be datetime objects, not floats

# %% [markdown]
# <em><b>Define</b></em>

# %% [markdown]
# Convert ArrTime, CRSDepTime, CRSArrTime, and DepTime columns to datetime

# %% [markdown]
# <em><b>Code</b></em>

# %%
#Credit to https://stackoverflow.com/questions/54313461/pandas-convert-float-to-proper-datetime-or-time-object
#Credit to https://stackoverflow.com/questions/13682044/remove-unwanted-parts-from-strings-in-a-column

#Convert 88 data

pgh_flights_88.ArrTime = pgh_flights_88.ArrTime.replace(".0", "")
pgh_flights_88.DepTime = pgh_flights_88.DepTime.replace(".0", "")
pgh_flights_88.CRSArrTime = pgh_flights_88.CRSArrTime.replace(".0", "")
pgh_flights_88.CRSDepTime = pgh_flights_88.CRSDepTime.replace(".0", "")

pgh_flights_88['ArrTime'] = pgh_flights_88['ArrTime'].str.zfill(4)
pgh_flights_88['DepTime'] = pgh_flights_88['DepTime'].str.zfill(4)
pgh_flights_88['CRSArrTime'] = pgh_flights_88['CRSArrTime'].str.zfill(4)
pgh_flights_88['CRSDepTime'] = pgh_flights_88['CRSDepTime'].str.zfill(4)

pgh_flights_88['ArrTime'] = pd.to_datetime(pgh_flights_88['ArrTime'], format='%H%M', errors='coerce').dt.time
pgh_flights_88['DepTime'] = pd.to_datetime(pgh_flights_88['DepTime'], format='%H%M', errors='coerce').dt.time
pgh_flights_88['CRSArrTime'] = pd.to_datetime(pgh_flights_88['CRSArrTime'], format='%H%M', errors='coerce').dt.time
pgh_flights_88['CRSDepTime'] = pd.to_datetime(pgh_flights_88['CRSDepTime'], format='%H%M', errors='coerce').dt.time

# %%
#Convert 07 data

pgh_flights_07.ArrTime = pgh_flights_07.ArrTime.replace(".0", "")
pgh_flights_07.DepTime = pgh_flights_07.DepTime.replace(".0", "")
pgh_flights_07.CRSArrTime = pgh_flights_07.CRSArrTime.replace(".0", "")
pgh_flights_07.CRSDepTime = pgh_flights_07.CRSDepTime.replace(".0", "")

pgh_flights_07['ArrTime'] = pgh_flights_07['ArrTime'].str.zfill(4)
pgh_flights_07['DepTime'] = pgh_flights_07['DepTime'].str.zfill(4)
pgh_flights_07['CRSArrTime'] = pgh_flights_07['CRSArrTime'].str.zfill(4)
pgh_flights_07['CRSDepTime'] = pgh_flights_07['CRSDepTime'].str.zfill(4)

pgh_flights_07['ArrTime'] = pd.to_datetime(pgh_flights_07['ArrTime'], format='%H%M', errors='coerce').dt.time
pgh_flights_07['DepTime'] = pd.to_datetime(pgh_flights_07['DepTime'], format='%H%M', errors='coerce').dt.time
pgh_flights_07['CRSArrTime'] = pd.to_datetime(pgh_flights_07['CRSArrTime'], format='%H%M', errors='coerce').dt.time
pgh_flights_07['CRSDepTime'] = pd.to_datetime(pgh_flights_07['CRSDepTime'], format='%H%M', errors='coerce').dt.time

# %% [markdown]
# <em><b>Test</b></em>

# %%
pgh_flights_88.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237901 entries, 15771 to 5184920
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               237901 non-null  int64
#  1   Month              237901 non-null  int64
#  2   DayofMonth         237901 non-null  int64
#  3   DayOfWeek          237901 non-null  int64
#  4   DepTime            235996 non-null  object
#  5   CRSDepTime         237901 non-null  object
#  6   ArrTime            235559 non-null  object
#  7   CRSArrTime         237901 non-null  object
#  8   UniqueCarrier      237901 non-null  object
#  9   FlightNum          237901 non-null  int64
#  10  TailNum            0 non-null       float64
#  11  ActualElapsedTime  235585 non-null  float64
#  12  CRSElapsedTime     237901 non-null  int64
#  13  AirTime            0 non-null       float64
#  14  ArrDelay           235585 non-null  float64
# ...

# %%
pgh_flights_88.head(2)
# Out:
#        Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 15771  1988      1           1          5  06:57:00   07:01:00  08:10:00
# 15772  1988      1           2          6  06:59:00   07:01:00  07:54:00
#
#       CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# 15771   07:44:00            TW         73  ...     NaN      NaN          0
# 15772   07:44:00            TW         73  ...     NaN      NaN          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 15771               NaN         0           NaN          NaN      NaN
# 15772               NaN         0           NaN          NaN      NaN
#
#        SecurityDelay  LateAircraftDelay
# 15771            NaN                NaN
# 15772            NaN                NaN
#
# [2 rows x 29 columns]

# %%
pgh_flights_07.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98419 entries, 194 to 7453089
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               98419 non-null  int64
#  1   Month              98419 non-null  int64
#  2   DayofMonth         98419 non-null  int64
#  3   DayOfWeek          98419 non-null  int64
#  4   DepTime            96257 non-null  object
#  5   CRSDepTime         98419 non-null  object
#  6   ArrTime            96082 non-null  object
#  7   CRSArrTime         98406 non-null  object
#  8   UniqueCarrier      98419 non-null  object
#  9   FlightNum          98419 non-null  int64
#  10  TailNum            98419 non-null  object
#  11  ActualElapsedTime  96107 non-null  float64
#  12  CRSElapsedTime     98406 non-null  float64
#  13  AirTime            96107 non-null  float64
#  14  ArrDelay           96107 non-null  float64
#  15  DepDelay           96271 non-null  float64
# ...

# %%
pgh_flights_07.head(2)
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 194   2007      1           1          1  10:34:00   10:35:00  12:32:00
# 1481  2007      1           2          2  10:37:00   10:35:00  17:54:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 194    12:50:00            WN       2999  ...      5       11          0
# 1481   17:45:00            WN        803  ...      4       15          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 194                NaN         0             0            0        0
# 1481               NaN         0             0            0        0
#
#       SecurityDelay  LateAircraftDelay
# 194               0                  0
# 1481              0                  0
#
# [2 rows x 29 columns]

# %% [markdown]
# #### 3. Several NaN columns for the pgh_flights_88 df

# %% [markdown]
# <em><b>Define</b></em>

# %% [markdown]
# Drop NaN columns (TailNum, AirTime, TaxiIn, TaxiOut, CancellationCode, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay) from pgh_flights_88 df

# %% [markdown]
# <em><b>Code</b></em>

# %%
columns=['TailNum', 'AirTime', 'TaxiIn', 'TaxiOut', 'CancellationCode', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']
pgh_flights_88.drop(columns, inplace=True, axis=1)

# %% [markdown]
# <em><b>Test</b></em>

# %%
pgh_flights_88.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237901 entries, 15771 to 5184920
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               237901 non-null  int64
#  1   Month              237901 non-null  int64
#  2   DayofMonth         237901 non-null  int64
#  3   DayOfWeek          237901 non-null  int64
#  4   DepTime            235996 non-null  object
#  5   CRSDepTime         237901 non-null  object
#  6   ArrTime            235559 non-null  object
#  7   CRSArrTime         237901 non-null  object
#  8   UniqueCarrier      237901 non-null  object
#  9   FlightNum          237901 non-null  int64
#  10  ActualElapsedTime  235585 non-null  float64
#  11  CRSElapsedTime     237901 non-null  int64
#  12  ArrDelay           235585 non-null  float64
#  13  DepDelay           236035 non-null  float64
#  14  Origin             237901 non-null  object
# ...

# %% [markdown]
# #### 4. Examine the delays outside of the larger 07 df

# %% [markdown]
# <em><b>Define</b></em>

# %% [markdown]
# Create a separate df for the flights from the 07 df which have delays and .

# %% [markdown]
# <em><b>Code</b></em>

# %%
delays_07 = pgh_flights_07.query("CarrierDelay != 0 or WeatherDelay != 0 or NASDelay != 0 or SecurityDelay != 0 or LateAircraftDelay != 0")

# %% [markdown]
# <em><b>Test</b></em>

# %%
delays_07.head(3)
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 1482  2007      1           2          2  15:04:00   14:35:00  22:19:00
# 2047  2007      1           2          2  14:00:00   13:35:00  16:08:00
# 2050  2007      1           2          2  17:30:00   16:55:00  19:39:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 1482   21:40:00            WN       2659  ...      7        8          0
# 2047   15:50:00            WN        304  ...      5        7          0
# 2050   19:15:00            WN        723  ...      4       11          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 1482               NaN         0             0           29       10
# 2047               NaN         0            10            0        0
# 2050               NaN         0             4            0        0
#
#       SecurityDelay  LateAircraftDelay
# 1482              0                  0
# ...

# %%
delays_07.query("CarrierDelay == 0 and WeatherDelay == 0 and NASDelay == 0 and SecurityDelay == 0 and LateAircraftDelay == 0")
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# This step successfully created a smaller dataframe consisting of only the flights which featured at least one type of the following 5 delays, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, and LateAircraftDelay. Now that the delays df has been created, the next two quality steps will create a column vital for this analysis and eliminate some outlandish outliers.

# %% [markdown]
# #### 5. There is no categorial column for delays which would be useful in visualization of the data

# %% [markdown]
# <em><b>Define</b></em>

# %% [markdown]
# Add a column to it which categorically captures the type of the delay, rather than just the time lost

# %% [markdown]
# <em><b>Code</b></em>

# %%
#Isolate Carrier delays and add them to a delaytype column in the df
carrier_delays = []

for _, flight in delays_07.iterrows():
    if flight.CarrierDelay != 0:
        carrier_delays.append('Carrier')
    else:
        carrier_delays.append('')

# %%
delays_07['DelayType'] = carrier_delays
delays_07.head(10)
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 1482  2007      1           2          2  15:04:00   14:35:00  22:19:00
# 2047  2007      1           2          2  14:00:00   13:35:00  16:08:00
# 2050  2007      1           2          2  17:30:00   16:55:00  19:39:00
# 2499  2007      1           2          2  18:36:00   18:10:00  19:55:00
# 2658  2007      1           2          2  15:55:00   14:50:00  21:45:00
# 2730  2007      1           2          2  20:27:00   19:55:00  22:37:00
# 2735  2007      1           2          2  20:12:00   19:40:00  20:30:00
# 2739  2007      1           2          2  22:02:00   21:20:00  23:01:00
# 4733  2007      1           3          3  15:03:00   14:35:00  21:57:00
# 5300  2007      1           3          3  17:29:00   16:55:00  19:45:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 1482   21:40:00            WN       2659  ...       8          0
# ...

# %%
#Add next delay type with string formatting for multiple delays
weather_delays = []

for _, flight in delays_07.iterrows():
    if flight.WeatherDelay != 0:
        weather_delays.append(', Weather')
    else:
        weather_delays.append('')

# %%
delays_07['DelayType'] = delays_07['DelayType'] + weather_delays
delays_07.head(10)
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 1482  2007      1           2          2  15:04:00   14:35:00  22:19:00
# 2047  2007      1           2          2  14:00:00   13:35:00  16:08:00
# 2050  2007      1           2          2  17:30:00   16:55:00  19:39:00
# 2499  2007      1           2          2  18:36:00   18:10:00  19:55:00
# 2658  2007      1           2          2  15:55:00   14:50:00  21:45:00
# 2730  2007      1           2          2  20:27:00   19:55:00  22:37:00
# 2735  2007      1           2          2  20:12:00   19:40:00  20:30:00
# 2739  2007      1           2          2  22:02:00   21:20:00  23:01:00
# 4733  2007      1           3          3  15:03:00   14:35:00  21:57:00
# 5300  2007      1           3          3  17:29:00   16:55:00  19:45:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 1482   21:40:00            WN       2659  ...       8          0
# ...

# %%
#Add next delay type with string formatting for multiple delays
NAS_delays = []

for _, flight in delays_07.iterrows():
    if flight.NASDelay != 0:
        NAS_delays.append(', NAS')
    else:
        NAS_delays.append('')

# %%
delays_07['DelayType'] = delays_07['DelayType'] + NAS_delays
delays_07.head(10)
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 1482  2007      1           2          2  15:04:00   14:35:00  22:19:00
# 2047  2007      1           2          2  14:00:00   13:35:00  16:08:00
# 2050  2007      1           2          2  17:30:00   16:55:00  19:39:00
# 2499  2007      1           2          2  18:36:00   18:10:00  19:55:00
# 2658  2007      1           2          2  15:55:00   14:50:00  21:45:00
# 2730  2007      1           2          2  20:27:00   19:55:00  22:37:00
# 2735  2007      1           2          2  20:12:00   19:40:00  20:30:00
# 2739  2007      1           2          2  22:02:00   21:20:00  23:01:00
# 4733  2007      1           3          3  15:03:00   14:35:00  21:57:00
# 5300  2007      1           3          3  17:29:00   16:55:00  19:45:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 1482   21:40:00            WN       2659  ...       8          0
# ...

# %%
#Add next delay type with string formatting for multiple delays
security_delays = []

for _, flight in delays_07.iterrows():
    if flight.SecurityDelay != 0:
        security_delays.append(', Security')
    else:
        security_delays.append('')

# %%
delays_07['DelayType'] = delays_07['DelayType'] + security_delays
delays_07.head(10)
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 1482  2007      1           2          2  15:04:00   14:35:00  22:19:00
# 2047  2007      1           2          2  14:00:00   13:35:00  16:08:00
# 2050  2007      1           2          2  17:30:00   16:55:00  19:39:00
# 2499  2007      1           2          2  18:36:00   18:10:00  19:55:00
# 2658  2007      1           2          2  15:55:00   14:50:00  21:45:00
# 2730  2007      1           2          2  20:27:00   19:55:00  22:37:00
# 2735  2007      1           2          2  20:12:00   19:40:00  20:30:00
# 2739  2007      1           2          2  22:02:00   21:20:00  23:01:00
# 4733  2007      1           3          3  15:03:00   14:35:00  21:57:00
# 5300  2007      1           3          3  17:29:00   16:55:00  19:45:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 1482   21:40:00            WN       2659  ...       8          0
# ...

# %%
#Add final delay type with string formatting for multiple delays
late_delays = []

for _, flight in delays_07.iterrows():
    if flight.LateAircraftDelay != 0:
        late_delays.append(', Late Aircraft')
    else:
        late_delays.append('')

# %%
delays_07['DelayType'] = delays_07['DelayType'] + late_delays
delays_07.head(10)
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 1482  2007      1           2          2  15:04:00   14:35:00  22:19:00
# 2047  2007      1           2          2  14:00:00   13:35:00  16:08:00
# 2050  2007      1           2          2  17:30:00   16:55:00  19:39:00
# 2499  2007      1           2          2  18:36:00   18:10:00  19:55:00
# 2658  2007      1           2          2  15:55:00   14:50:00  21:45:00
# 2730  2007      1           2          2  20:27:00   19:55:00  22:37:00
# 2735  2007      1           2          2  20:12:00   19:40:00  20:30:00
# 2739  2007      1           2          2  22:02:00   21:20:00  23:01:00
# 4733  2007      1           3          3  15:03:00   14:35:00  21:57:00
# 5300  2007      1           3          3  17:29:00   16:55:00  19:45:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 1482   21:40:00            WN       2659  ...       8          0
# ...

# %%
#Two cleaning steps in one. The following step fixes a self-created data quality issue with a quick stripping of unnecessary leading characters
#Fix leading (, ) on rows which did not have a preceeding delay type
#Credit to https://stackoverflow.com/questions/45923189/remove-first-character-from-pandas-column-if-the-number-1
delays_07['DelayType'] = delays_07['DelayType'].apply(lambda x : x[2:] if x.startswith(", ") else x)

# %% [markdown]
# <em><b>Test</b></em>

# %%
delays_07.head(10)
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 1482  2007      1           2          2  15:04:00   14:35:00  22:19:00
# 2047  2007      1           2          2  14:00:00   13:35:00  16:08:00
# 2050  2007      1           2          2  17:30:00   16:55:00  19:39:00
# 2499  2007      1           2          2  18:36:00   18:10:00  19:55:00
# 2658  2007      1           2          2  15:55:00   14:50:00  21:45:00
# 2730  2007      1           2          2  20:27:00   19:55:00  22:37:00
# 2735  2007      1           2          2  20:12:00   19:40:00  20:30:00
# 2739  2007      1           2          2  22:02:00   21:20:00  23:01:00
# 4733  2007      1           3          3  15:03:00   14:35:00  21:57:00
# 5300  2007      1           3          3  17:29:00   16:55:00  19:45:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 1482   21:40:00            WN       2659  ...       8          0
# ...

# %% [markdown]
# As you can see, the delays df now features a column which captures each flights unique combination of delays experienced.

# %% [markdown]
# #### 6. There are a few extremely large delay times which greatly skew the delays df

# %% [markdown]
# <em><b>Define</b></em>

# %% [markdown]
# Identify and drop the rows which contain significant outliers

# %% [markdown]
# <em><b>Code</b></em>

# %%
delays_07[['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']].describe()
# Out:
#        CarrierDelay  WeatherDelay      NASDelay  SecurityDelay  \
# count  26090.000000  26090.000000  26090.000000   26090.000000
# mean      15.028363      3.138750     16.793024       0.083212
# std       39.312044     17.926633     32.098419       2.072162
# min        0.000000      0.000000      0.000000       0.000000
# 25%        0.000000      0.000000      0.000000       0.000000
# 50%        0.000000      0.000000      6.000000       0.000000
# 75%       16.000000      0.000000     21.000000       0.000000
# max     1655.000000    422.000000   1079.000000     221.000000
#
#        LateAircraftDelay
# count       26090.000000
# mean           22.570410
# std            41.748367
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%            29.000000
# max           540.000000

# %% [markdown]
# It appears that every column has at least one extremely high value (200+ minutes of delay time) for a row(s). Let's look at all the rows with a delaytime of more than 29 minutes, the highest of the 75% values for the 5 delay columns

# %%
delays_07.query("CarrierDelay > 29 or WeatherDelay > 29 or NASDelay > 29 or SecurityDelay > 29 or LateAircraftDelay > 29")
# Out:
#          Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 2658     2007      1           2          2  15:55:00   14:50:00  21:45:00
# 9237     2007      1           4          4  20:03:00   19:40:00  20:59:00
# 12253    2007      1           5          5  23:29:00   21:45:00  00:33:00
# 12256    2007      1           5          5  21:12:00   18:10:00  22:27:00
# 12485    2007      1           5          5  22:45:00   19:55:00  00:44:00
# ...       ...    ...         ...        ...       ...        ...       ...
# 7441023  2007     12           5          3  08:00:00   06:00:00  10:36:00
# 7443838  2007     12           7          5  16:30:00   16:35:00  19:52:00
# 7445552  2007     12           9          7  10:12:00   10:10:00  16:32:00
# 7446254  2007     12           9          7  17:07:00   16:35:00  19:31:00
# 7451478  2007     12          13          4  05:57:00   06:00:00  08:44:00
#
# ...

# %% [markdown]
# 13934 rows. That is still a lot of rows. Let us see how many rows have a delay with more than 100 minutes of delay time

# %%
delays_07.query("CarrierDelay > 100 or WeatherDelay > 100 or NASDelay > 100 or SecurityDelay > 100 or LateAircraftDelay > 100")
# Out:
#          Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 12256    2007      1           5          5  21:12:00   18:10:00  22:27:00
# 12485    2007      1           5          5  22:45:00   19:55:00  00:44:00
# 12493    2007      1           5          5  19:21:00   16:15:00  20:43:00
# 12494    2007      1           5          5  22:23:00   21:20:00  00:45:00
# 12497    2007      1           5          5  16:50:00   14:40:00  17:55:00
# ...       ...    ...         ...        ...       ...        ...       ...
# 7407314  2007     12          31          1  22:31:00   19:30:00  00:28:00
# 7415556  2007     12           3          1  10:44:00   08:45:00  12:03:00
# 7432686  2007     12          15          6  15:33:00   13:25:00  19:02:00
# 7433295  2007     12          15          6  19:51:00   17:53:00  22:29:00
# 7441023  2007     12           5          3  08:00:00   06:00:00  10:36:00
#
# ...

# %% [markdown]
# Now, only 3083 rows of the original 26090 rows in the delays_07 df are collected. This is still a lot of rows to drop, so we will try greater than 200 minutes of delay time and determine if it helps eliminate the extreme outliers while also not eliminating too much of the DF

# %%
delays_07.query("CarrierDelay > 200 or WeatherDelay > 200 or NASDelay > 200 or SecurityDelay > 200 or LateAircraftDelay > 200")
# Out:
#          Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 94787    2007      1           1          1  21:32:00   17:30:00  23:18:00
# 96638    2007      1           5          5  20:04:00   16:40:00  21:41:00
# 101078   2007      1           1          1  23:42:00   19:40:00  01:04:00
# 105092   2007      1          17          3  17:20:00   11:50:00  18:58:00
# 112927   2007      1           7          7  15:14:00   10:50:00  18:16:00
# ...       ...    ...         ...        ...       ...        ...       ...
# 7316754  2007     12          25          2  17:02:00   13:26:00  20:48:00
# 7316797  2007     12          25          2  21:07:00   17:00:00  22:25:00
# 7399503  2007     12          17          1  13:05:00   07:00:00  14:30:00
# 7403024  2007     12          23          7  00:18:00   18:45:00  01:56:00
# 7405538  2007     12          28          5  23:26:00   19:30:00  01:18:00
#
# ...

# %% [markdown]
# There we have it. Less than 600 of the flights in the delays_07 df feature a delay of more than 200 minutes. While these extreme delays could be valuable for different insights, they are greatly skewing the overall delay_07 df and making analysis of average delay related exporation more difficult.

# %% [markdown]
# <em><b>Code</b></em>

# %%
#Select rows which have less than 200 delay time in any of the 5 columns of interest
delays_07.query("CarrierDelay <= 200 and WeatherDelay <= 200 and NASDelay <= 200 and SecurityDelay <= 200 and LateAircraftDelay <= 200")
# Out:
#          Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 1482     2007      1           2          2  15:04:00   14:35:00  22:19:00
# 2047     2007      1           2          2  14:00:00   13:35:00  16:08:00
# 2050     2007      1           2          2  17:30:00   16:55:00  19:39:00
# 2499     2007      1           2          2  18:36:00   18:10:00  19:55:00
# 2658     2007      1           2          2  15:55:00   14:50:00  21:45:00
# ...       ...    ...         ...        ...       ...        ...       ...
# 7449494  2007     12          12          3  15:24:00   15:10:00  17:03:00
# 7450143  2007     12          12          3  11:37:00   11:05:00  13:28:00
# 7450160  2007     12          12          3  14:03:00   13:32:00  15:42:00
# 7451478  2007     12          13          4  05:57:00   06:00:00  08:44:00
# 7452930  2007     12          14          5  16:42:00   16:35:00  19:21:00
#
# ...

# %%
#Set that selected data as the delays_07 df
delays_07 = delays_07.query("CarrierDelay <= 200 and WeatherDelay <= 200 and NASDelay <= 200 and SecurityDelay <= 200 and LateAircraftDelay <= 200")

# %% [markdown]
# <em><b>Code</b></em>

# %%
delays_07.describe()
# Out:
#           Year         Month    DayofMonth     DayOfWeek     FlightNum  \
# count  25515.0  25515.000000  25515.000000  25515.000000  25515.000000
# mean    2007.0      6.233431     15.800235      3.886106   2599.530159
# std        0.0      3.476602      8.597204      1.960544   1888.638510
# min     2007.0      1.000000      1.000000      1.000000      1.000000
# 25%     2007.0      3.000000      8.000000      2.000000   1058.000000
# 50%     2007.0      6.000000     16.000000      4.000000   1830.000000
# 75%     2007.0      9.000000     23.000000      5.000000   3750.000000
# max     2007.0     12.000000     31.000000      7.000000   7497.000000
#
#        ActualElapsedTime  CRSElapsedTime       AirTime      ArrDelay  \
# count       25515.000000    25515.000000  25515.000000  25515.000000
# mean          125.724397      116.547208     92.386518     52.203371
# std            57.601936       53.804844     56.475078     42.085848
# ...

# %% [markdown]
# As you can see, the new delays_07 df has 575 less values than the original and none of the 5 delay columns which are being examined has more than a 200 minute maximum delay time.

# %% [markdown]
# ## Data Exploration <a name="data_exploration"></a>

# %% [markdown]
# As discussed earlier, there are at least seven aspects of this data which will be examined in greater detail. They are:
# <ul>
#     <li>The most popular month for travel in 88 and 07</li>
#     <li>The most popular day of the week for travel in 88 and 07</li>
#     <li>The most popular origins for flights arriving in Pittsburgh</li>
#     <li>The most popular destinations for flights departing from Pittsburgh</li>
#     <li>The length of flights</li>
#     <li>The length of delays for flights that experience them</li>
#     <li>The most common type of delay</li>
# </ul>
#
# They will undergo Univariate Exploration and some many be combined in bivariate or multivariate exploration if their results encourage a deeper exploration.

# %% [markdown]
# ### Univariate Exploration <a name="univariate_exploration"></a>

# %% [markdown]
# #### 1. Most Popular Month to Fly

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
base_color = sns.color_palette()[0]

fig = plt.figure(figsize=(10,5))
fig.suptitle('Flights to and from Pittsburgh by Month in 1988 and 2007')
#Establish the figure and build the subplots individually
plt.subplot(1, 2, 1)
mon_fly_88 = pgh_flights_88['Month'].value_counts().sort_index()

#1988 monthly flight data
g=sns.barplot(x=mon_fly_88.index, y=mon_fly_88, color=base_color)
g.set_xticklabels(labels=months)
g.set_ylabel('Flight Count', fontsize=12)
g.set_xlabel('Months (1988)', fontsize=12)
g.set_ylim(18000, 21100);

plt.subplot(1, 2, 2)
mon_fly_07 = pgh_flights_07['Month'].value_counts().sort_index()

#2007 monthly flight data
g=sns.barplot(x=mon_fly_07.index, y=mon_fly_07, color=base_color)
g.set_xticklabels(labels=months)
g.set_ylabel('Flight Count', fontsize=12)
g.set_xlabel('Months (2007)', fontsize=12)
g.set_ylim(7000, 9100);

# %% [markdown]
# <em>Please take note that these figures utilize y-variable limits to more close exaine the difference between each month's flight data. The differences between one month to the other is not based from 0, but from 18,000 in 1988 and 7000 in 2007. The greatest difference between months is less than 3000 flights in 1988 and just over 2000 flights in 2007.</em>
#
# It can be seen that travel to and from Pittsburgh is higher in the summer months, especially in 1988. February is very low for travel in both years and the winter months see less travel overall. It should also be noted that there is a significant difference in the amount of flights in 1988 and 2007. There are many factors which contributed to this difference, but it does not appear to have changed the preferred time to travel in too significant a way, mosly a reversal of preference over flying in December in 2018 and in January in 2007.

# %% [markdown]
# #### 2. Most Popular Day of the Week to Fly

# %%
days_of_week = ['Mon', 'Tues', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
base_color = sns.color_palette()[0]

fig = plt.figure(figsize=(12,6))
fig.suptitle('Flights to and from Pittsburgh by Day of the Week in 1988 and 2007')
#Set up the figure and subplots
plt.subplot(1, 2, 1)
day_fly_88 = pgh_flights_88['DayOfWeek'].value_counts().sort_index()

#Plot the 1988 day of week flight data
g=sns.barplot(x=day_fly_88.index, y=day_fly_88, color=base_color)
g.set_xticklabels(labels=days_of_week)
g.set_ylabel('Flight Count', fontsize=12)
g.set_xlabel('Day of the Week (1988)', fontsize=12)
g.set_ylim(33000, 34750);

plt.subplot(1, 2, 2)
day_fly_07 = pgh_flights_07['DayOfWeek'].value_counts().sort_index()

#Plot the 2007 day of week flight data
g=sns.barplot(x=day_fly_07.index, y=day_fly_07, color=base_color)
g.set_xticklabels(labels=days_of_week)
g.set_ylabel('Flight Count', fontsize=12)
g.set_xlabel('Day of the Week (2007)', fontsize=12)
g.set_ylim(11500, 14900);

# %% [markdown]
# <em>Please take note that these figures utilize y-variable limits to more close exaine the difference between each day of the week's flight data. The differences between one day of the week to the other is not based from 0, but from 33,000 in 1988 and 11500 in 2007. The greatest difference between days of the week is less than 2000 flights in 1988 and just over 3000 flights in 2007.</em>
#
# Like the charts related to montly travel, there is a similar pattern of weekday travel being higher in both 1988 and 2007. Weekends do not see as many flights, though Sundays received a significant uptick from 1988 to 2007. The higher values for weekday travel could suggest that travel related to business is more common in Pittsburgh, especially in 1988. Regardless, Saturday is the least preferred day to travel in both 1988 and 2007.

# %% [markdown]
# #### 3. Most Popular Flight Origin

# %%
#accumulate flights arriving in pittsburgh aka those not originating in Pittsburgh in 1988
origins88 = pgh_flights_88.query("Origin != 'PIT'").Origin.value_counts()

# %%
print(origins88)
# Out:
# ORD    6307
# ATL    5125
# EWR    4533
# PHL    3753
# DTW    3739
#        ...
# LAS     240
# GSP     153
# ORH     117
# MYR      34
# CAK       3
# Name: Origin, Length: 79, dtype: int64

# %%
#Examine the top 6 as they are are somewhat outliers
origins88[:6]
# Out:
# ORD    6307
# ATL    5125
# EWR    4533
# PHL    3753
# DTW    3739
# LGA    3397
# Name: Origin, dtype: int64

# %%
bins = np.arange(0, origins88.max() + 300, 250)
plt.hist(origins88, bins = bins)
plt.xlabel('Number of Flights (Increments of 250)', fontsize=12)
plt.ylabel('Airport Count', fontsize=12)
plt.title('Flight Count Grouped by Origination Airport in 1988 - 79 Different Airports');

# %% [markdown]
# In the above figure it is clear that most airports, which flights to Pittsburgh originated from, featured 2000 or less flights in 1988.  However, 6 airports each sent more than 3000 flights a year to Pittsburgh. These are the numbers for those 6 airports: LaGuardia in NYC sent 3397 flights, Detroit sent 3739 flights, Philadelphia sent 3753 flights, Newark sent 4533 flights, Atlanta sent 5125 flights, and Chicago O'Hare sent 6307 flights.

# %%
#accumulate flights arriving in pittsburgh in 2007 as well
origins07 = pgh_flights_07.query("Origin != 'PIT'").Origin.value_counts()

# %%
print(origins07)
print(len(origins07), 'origins')
# Out:
# ATL    4492
# ORD    4386
# PHL    3457
# JFK    2524
# LGA    2522
# MCO    2426
# EWR    2349
# DFW    2305
# CLT    2146
# MDW    2053
# DTW    1912
# IAH    1730
# IAD    1546
# BOS    1511
# LAS    1372
# CVG    1370
# MSP    1325
# DEN    1253
# PHX    1090
# MEM     977
# TPA     914
# BWI     886
# MKE     754
# FLL     751
# DCA     625
# MIA     509
# LAX     440
# SFO     429
# MCI     390
# SLC     305
# RSW     193
# PBI     172
# SJU      52
# SEA      19
# MYR      13
# SAN      12
# Name: Origin, dtype: int64
# 36 origins

# %%
bins = np.arange(0, origins07.max() + 300, 250)
plt.hist(origins07, bins = bins)
plt.xlabel('Number of Flights (Increments of 250)', fontsize=12)
plt.ylabel('Airport Count', fontsize=12)
plt.title('Flight Count Grouped by Origination Airport in 2007 - 36 Different Airports');

# %% [markdown]
# Similar to the previous figure, the majority of aiports which sent flights to Pittsburgh in 2007 sent less than 3000. However, there were 3 airports which still sent over 3000. They were Philadelphia at 3457 flights (overtaking Newark from 1988), Chicago O'Hare with 4386 flights and Atlanta with 4492 flights(overtaking O'Hare).

# %% [markdown]
# Now, for anyone who does not fly or know very much about air travel, there are smaller local airports, medium-sized regional airports, and large airports known as hubs. Atantla has become the busiest airport on the East Coast, so that is why it sends and receives so many flights to/from Pittsburgh, a "medium-sized" airport. Chicago, Detriot, Philadelphia, and the NYC airports are also larger airports than Pittsburgh, with some of them being hubs as well.
#
# Due to this relationship of airports, the following figures related to destinations from Pittsburgh will also likely send the most flights to these significant hubs (to transfer to another flight) more than the regional(medium) or local(small) airports.

# %% [markdown]
# #### 4. Most Popular Flight Destination

# %%
#accumulate flights leaving Pittsburgh aka those not destined for Pittsburgh in 1988
destinations88 = pgh_flights_88.query("Dest != 'PIT'").Dest.value_counts()

# %%
print(destinations88)
# Out:
# ORD    6355
# ATL    5104
# EWR    4434
# PHL    3818
# DTW    3780
#        ...
# LAS     234
# GSP     144
# ORH     116
# MYR      34
# TUS       1
# Name: Dest, Length: 79, dtype: int64

# %%
destinations88[:6]
# Out:
# ORD    6355
# ATL    5104
# EWR    4434
# PHL    3818
# DTW    3780
# LGA    3474
# Name: Dest, dtype: int64

# %%
bins = np.arange(0, destinations88.max() + 300, 250)
plt.hist(destinations88, bins = bins)
plt.xlabel('Number of Flights (Increments of 250)', fontsize=12)
plt.ylabel('Airport Count', fontsize=12)
plt.title('Flight Count Grouped by Destination Airport in 1988 - 79 Different Airports');

# %% [markdown]
# Flights originating in Pittsburgh usually went to each airport less than 3000 times in 1988.  However, again, 6 airports received more than 3000 flights a year from Pittsburgh. These are the numbers for those 6 airports: LaGuardia in NYC received 3474 flights, Detroit received 3780 flights, Philadelphia received 3818 flights, Newark received 4434 flights, Atlanta received 5104 flights, and Chicago O'Hare received 6355 flights.

# %%
#accumulate flights leaving Pittsburgh in 2007
destinations07 = pgh_flights_07.query("Dest != 'PIT'").Dest.value_counts()

# %%
print(destinations07)
print(len(destinations07), 'destinations')
# Out:
# ATL    4485
# PHL    4305
# ORD    4284
# JFK    2526
# MCO    2422
# EWR    2349
# DFW    2308
# LGA    2155
# MDW    2063
# CLT    2006
# DTW    1948
# IAH    1729
# BOS    1562
# IAD    1541
# LAS    1373
# CVG    1371
# MSP    1292
# DEN    1253
# PHX    1090
# MEM     975
# TPA     915
# BWI     876
# MKE     744
# FLL     692
# MIA     508
# LAX     441
# SFO     429
# DCA     399
# MCI     391
# SLC     304
# RSW     194
# PBI     172
# SJU      52
# SEA      19
# MYR      13
# SAN      12
# GRR       2
# MSN       2
# PWM       1
# COS       1
# CAE       1
# TYS       1
# PVD       1
# CMH       1
# DSM       1
# Name: Dest, dtype: int64
# 45 destinations

# %%
bins = np.arange(0, destinations07.max() + 300, 250)
plt.hist(destinations07, bins = bins)
plt.xlabel('Number of Flights (Increments of 250)', fontsize=12)
plt.ylabel('Airport Count', fontsize=12)
plt.title('Flight Count Grouped by Destination Airport in 2007 - 45 Different Airports');

# %% [markdown]
# Similar to the previous graph, the majority of airports which received flights from Pittsburgh in 2007 received less than 2750 flights. In fact, 1/3 of the 45 airports received less than 250 flights from Pittsburgh. However, there were 3 airports which still received well more than 2750. They were Chicago O'Hare with 4284 flights, Philadelphia at 4305 flights (overtaking Newark and Chicago), and Atlanta with 4485 flights(overtaking O'Hare). Interestingly, Pittsburgh sent flights to 9 more airports than it received flights from in 2007. This is another example of how air travel through Pittsburgh changed over the 20 year period from 1988 to 2007.

# %% [markdown]
# #### 5. Flight Length

# %%
base_color = sns.color_palette()[0]
bins = np.arange(0, pgh_flights_88.ActualElapsedTime.max()+ 25, 25)

fig = plt.figure(figsize=(12,6))
fig.suptitle('Flight time for flights to and from Pittsburgh in 1988 and 2007')
#Set up the figure and the subplots
plt.subplot(1, 2, 1)
plt.hist(pgh_flights_88.ActualElapsedTime, bins = bins)
plt.ylabel('Flight Count', fontsize=12)
plt.xlabel('Elapsed Time (25 Minute Increments)', fontsize=12);

#Use the same bins for the 07 data for consistency in initial comparison
plt.subplot(1, 2, 2)
plt.hist(pgh_flights_07.ActualElapsedTime, bins = bins)
plt.ylabel('Flight Count', fontsize=12)
plt.xlabel('Elapsed Time (25 Minute Increments)', fontsize=12);

# %% [markdown]
# These first two figures show that a lot flights were 100 minutes or less in Elapsed Time and the data was somewhat right skewed. The following figures will show the normal and log-transformed data for both 1988 and 2007 flight length data.

# %%
# Credit to https://stackoverflow.com/questions/8248467/matplotlib-tight-layout-doesnt-take-into-account-figure-suptitle
# Credit to https://stackoverflow.com/questions/13228254/subplots-are-overlapping-axis-labels
base_color = sns.color_palette()[0]
#This time create bins for each year
bins_88 = np.arange(0, pgh_flights_88.ActualElapsedTime.max()+ 25, 25)
bins_07 = np.arange(0, pgh_flights_07.ActualElapsedTime.max()+ 25, 25)

fig = plt.figure(figsize=(12,6))
fig.suptitle('Flight time for flights to and from Pittsburgh in 1988 and 2007 (Standard and Log of the Data)', y = 1.05)

#Subplot 1
plt.subplot(2, 2, 1)
plt.tight_layout()
plt.hist(pgh_flights_88.ActualElapsedTime, bins = bins_88)
plt.xlim(0,400)
plt.ylabel('Flight Count', fontsize=12)
plt.xlabel('Elapsed Time (Minutes)', fontsize=12)
plt.title("1988", x=0.9);

#Subplot 2
plt.subplot(2, 2, 2)
plt.tight_layout()
plt.hist(pgh_flights_07.ActualElapsedTime, bins = bins_07)
plt.xlim(0,400)
plt.ylabel('Flight Count', fontsize=12)
plt.xlabel('Elapsed Time (Minutes)', fontsize=12)
plt.title("2007", x=0.9);

#Create log data for transformation and bins for each year
log_data_88 = np.log10(pgh_flights_88.ActualElapsedTime) 
log_bins_88 = np.arange(log_data_88.min(), log_data_88.max(), .1)
log_data_07 = np.log10(pgh_flights_07.ActualElapsedTime)
log_bins_07 = np.arange(log_data_07.min(), log_data_07.max(), .1)
log_ticks = [1.4, 1.6, 1.8, 2.0, 2.2, 2.4, 2.6]
log_labels = ['25', '40', '60', '100', '160', '250', '400']

#Subplot 3
plt.subplot(2, 2, 3)
plt.tight_layout()
plt.hist(log_data_88, bins = log_bins_88)
plt.xscale('log')
plt.ylabel('Flight Count', fontsize=12)
#adjusted the xlim on the left side of the figure to keep the two log subplots as consistent as possible
plt.xlim(1.4,)
plt.xlabel('Elapsed Time (Minutes)', fontsize=12)
plt.xticks(log_ticks, log_labels)
plt.title("1988 (Log Data)", x=0.9);

#Subplot 4
plt.subplot(2, 2, 4)
plt.tight_layout()
plt.hist(log_data_07, bins = log_bins_07)
plt.xscale('log')
plt.ylabel('Flight Count', fontsize=12)
plt.xlabel('Elapsed Time (Minutes)', fontsize=12)
plt.xticks(log_ticks, log_labels)
plt.title("2007 (Log Data)", x=0.9);

# %% [markdown]
# In the 6 figures above you saw the basic histogram of flight time for both 1988 and 2007 and then saw it again directly next to its log equivalent. The log of the flight time data is much easier to interpret with a nice normal distribution, especially for flights in 1988. Most flights were between approximately 50 minutes and 100 minutes. Some short hoppers were less than 50 minutes and some long-hauls lasted upwards of 300 minutes (5 hours)! The data from 2007 suggests that flights to and from Pittsburgh were generally a little longer than in 1988. There were no flights with a time shorter than 40 minutes and a few more data points on the upper end of the distribution.

# %% [markdown]
# #### 6. Delay Length

# %%
#Standard Data Histogram Subplots
fig = plt.figure(figsize=(12, 6))
plt.subplots_adjust(top=2, bottom=.1)


plt.subplot(3, 2, 1)
delays_07.CarrierDelay.hist()
plt.ylabel('Flight Count')
plt.xlabel('Carrier Delay (Minutes)')
plt.title('Flight Count for Carrier Delays Times (Minutes)');

plt.subplot(3, 2, 2)
delays_07.WeatherDelay.hist()
plt.ylabel('Flight Count')
plt.xlabel('Weather Delay (Minutes)')
plt.title('Flight Count for Weather Delays Times (Minutes)');

plt.subplot(3, 2, 3)
delays_07.NASDelay.hist()
plt.ylabel('Flight Count')
plt.xlabel('NAS Delay (Minutes)')
plt.title('Flight Count for NAS  Times (Minutes)');

plt.subplot(3, 2, 4)
delays_07.SecurityDelay.hist()
plt.ylabel('Flight Count')
plt.xlabel('Security Delay (Minutes)')
plt.title('Flight Count for Security Delay Times (Minutes)');

plt.subplot(3, 2, 5)
delays_07.LateAircraftDelay.hist()
plt.ylabel('Flight Count')
plt.xlabel('Late Aircraft Delay (Minutes)')
plt.title('Flight Count for Late Aircraft Delay Times (Minutes)');

# %% [markdown]
# As these 5 histograms show, the data is heavily skewed to the right, with most delay times for each type of delay being less than 25 minutes long. However, please keep in mind that earlier wrangling of this data did drop some extreme data outliers (any delays longer than 200 minutes), but that was less than 600 flights of the over 26,000 in the original delays_07 df. This data could be examined with a log transformation for a little more clarity, but the overall message is that most delays are well under an hour if not less than 30 minutes.
#
# However, what if you are unfortunate to be on a flight which is the victim of multiple delays? To examine this train of thought we will first create and look at the total delay time for each type of delay. Then we will use this information and make the first of several bivariate figures to further explore this data and other aspects of the univariate analysis.

# %%
#Create total delay time for each type of delay
carrier_total = delays_07.CarrierDelay.sum()
nas_total = delays_07.NASDelay.sum()
weather_total = delays_07.WeatherDelay.sum()
security_total = delays_07.SecurityDelay.sum()
late_total = delays_07.LateAircraftDelay.sum()

# %%
#Create labels for delay types and the data for them
x_val = ['CarrierDelay',  'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']
x_labels=['Carrier', 'Weather', 'NAS', 'Security', 'Late Aicraft']
y_val = [carrier_total, weather_total, nas_total, security_total, late_total]

fig, ax = plt.subplots()
width = 0.75
ax.bar(x=x_val, height=y_val, width=width)
ax.set_xticklabels(x_labels, rotation=30)
plt.ylabel('Total Delay Time (Minutes)', fontsize=12)
plt.xlabel('Delay Type', fontsize=12)
plt.ylim(0,600000)

#Plot the value of each bar
for i, v in enumerate(y_val): #Credit - https://stackoverflow.com/questions/30228069/how-to-display-the-value-of-the-bar-on-each-bar-with-pyplot-barh
    ax.text(i -.3, v + 5000, str(v), color='black')
plt.title('The Total Delay Time in Minutes for Each Delay Type');

# %% [markdown]
# The delay time by delay type figure shows that a late aircraft has acrued the most delay time in 2007 with 525,707 minutes or 365 days, 1 hour and 47  minutes! Perhaps surprisingly, weather did not result in nearly as much delay time in Pittsburgh in 2007, but still accumulated 68,972 minutes or 47 days 21 hours and 32 minutes worth of delays. Lastly, it is nice to note that less than 2,000 minutes of delays were attributed to security related issues in 2007.

# %% [markdown]
# ### Bivariate Exploration <a name="bivariate_exploration"></a>

# %% [markdown]
# For the Bivariate Exploration, lets first jump right into the delays dataframe and see what delay type combinations lead to the most significant delays. It is possible that a flight could experience all or none of these five delay types this data examines. However, given the method of acquiring this dataframe, every flight should have experienced at least one type of delay and none of the delays will be over 200 minutes (individually). Unfortunately, some of the outliers of 200+ minutes worth of delay made the data much more difficult to visualize efficiently and were left out in the earlier cleaning.

# %% [markdown]
# #### 1. Total delay time and delay type

# %%
#Create a total delay time column
delays_07['total_delay'] = (delays_07.CarrierDelay + delays_07.WeatherDelay + delays_07.NASDelay + delays_07.SecurityDelay + delays_07.LateAircraftDelay)

# %%
delays_07.head()
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 1482  2007      1           2          2  15:04:00   14:35:00  22:19:00
# 2047  2007      1           2          2  14:00:00   13:35:00  16:08:00
# 2050  2007      1           2          2  17:30:00   16:55:00  19:39:00
# 2499  2007      1           2          2  18:36:00   18:10:00  19:55:00
# 2658  2007      1           2          2  15:55:00   14:50:00  21:45:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... Cancelled  CancellationCode  \
# 1482   21:40:00            WN       2659  ...         0               NaN
# 2047   15:50:00            WN        304  ...         0               NaN
# 2050   19:15:00            WN        723  ...         0               NaN
# 2499   19:25:00            WN       1597  ...         0               NaN
# 2658   20:55:00            WN        647  ...         0               NaN
#
#       Diverted  CarrierDelay  WeatherDelay  NASDelay SecurityDelay  \
# ...

# %%
delays_07.total_delay.describe()
# Out:
# count    25515.000000
# mean        52.203371
# std         42.085848
# min         15.000000
# 25%         23.000000
# 50%         36.000000
# 75%         66.000000
# max        355.000000
# Name: total_delay, dtype: float64

# %% [markdown]
# Notice the new total delay column does feature delay times greater than 200, but this is from a combination of delays. None of the individual flights includes any delay times greater than 200 minutes for these 5 delay types.

# %%
delay_bins = np.arange(delays_07.total_delay.min() - 5, delays_07.total_delay.max() +5, 50)

# %%
base_color = sns.color_palette()[1]
fig = plt.figure(figsize=(16,8))
sns.boxplot(data=delays_07, x='DelayType', y='total_delay', color=base_color)
plt.xticks(rotation=65)
plt.ylim(0, 360)
plt.title('Total Delay Time for Each Flight Based on Delay Types Experienced')
plt.ylabel('Total Delay per Flight (Minutes)', fontsize=12)
plt.xlabel('Delay Combinations', fontsize=12);

# %% [markdown]
# A lot of cleaning of the delays_07 sub dataframe went into creating the 19 different delay combinations you see in the above figure. There were actually more possible, but the data for pittsburgh delays did not feature some of the combinations. For example, no flight in or out of Pittsburgh in 2007 dealt with all 5 types of delays (thankfully)! However, a few did experience flights which dealt with every delay, but security!  This figure shows the total delay time for each of their individual delay type combinations.
#
# Late aircraft delays seems to lead to the largest outliers of the above data. While occuring individually, a late aircraft delay is very similar to Carrier, Weather, and NAS delays. Though, when it is combined with 1-2 other delay types it results in  some larger outliers of close to or more than 350 minutes of combined delay time! Additionally, security delays are infrequent in all combinations, appearing in only 5 of the 19 delay combinations experienced. They also do not appear to do much to alter the overall delay time of any of their combinations. This was supported earlier by that delay type featuring a very small total delay time compared to the other delay categories when examined in the univariate analysis.

# %% [markdown]
# #### 2. Busiest day of the week to travel by month

# %% [markdown]
# Now that you have seen how each delay combination has a different impact on flights, lets jump back to some of the other categories we looked at in the Univariate Exploration. Earlier the month and day of the week were analyzed individually, so it seems natural to look at them together to see if they present any deeper insights into the data.
#
# Remember, Summer was generally more popular to travel in than Winter, with February being the least frequent. Also weekdays were preferred over weekends, with Saturdays as the least favorite in both 1988 and 2007.

# %%
fig, ax = plt.subplots(figsize=(16,8))
plt.suptitle('The Total Number of Flights Broken Down by Month and then Day of the Week (1988)')
color = sns.color_palette("colorblind")

#1988
sns.countplot(data=pgh_flights_88, x = 'Month', hue = 'DayOfWeek', ax=ax, palette=color)
ax.set_xticklabels(labels=months)
ax.legend(labels=days_of_week, title='Day of the Week', loc='upper left')
ax.set_ylim(2250,)
ax.set_ylabel('Flight Count (Starting at 2250 Flights)');

# %%
fig, ax = plt.subplots(figsize=(16,8))
plt.suptitle('The Total Number of Flights Broken Down by Month and then Day of the Week (2007)')

sns.countplot(data=pgh_flights_07, x = 'Month', hue = 'DayOfWeek', ax=ax, palette=color)
ax.set_xticklabels(labels=months)
ax.legend(labels=days_of_week, title='Day of the Week')
ax.set_ylim(800,)
ax.set_ylabel('Flight Count (Starting at 800 Flights)');

# %% [markdown]
# <em>Before looking at anything else, it is important to note that both of the figures above feature an adjusted ylimit to look at the data more closely. In the 1988 plot the data starts at 2250 and in the 2007 figure it starts at 800. This means that the differences in flights are not quite as extreme as they appear when compared to one another. </em>
#
# Now, the above countplots appear to be filled with a lot of data, but it is really quite straightforward when you examine it piece by piece. Simply, each figure shows breaks the flight count down by month and then divides it up by the day of the week. For example, Saturdays in January of 2007 saw only around 900 total flights while Mondays, Tuesdays, and Wednesdays of the same month/year each had a total of around 1400 flights! If you recall, Saturdays were the least popular day of the week to travel overall in 1988 and 2007, so it is not surprising that it is the least preferred day of the week to travel in almost every month of both 1988 and 2007.  10/12 months in 2007 had it as the least popular, with March and June seeing Sunday as the least popular. In 1988 every month had Saturday as the least popular day to travel, excluding December which people traveled the least on Sundays.
#
# What these figures allow you to efficiently see, which the two independent examinations in the univariate analysis did not, is that each month/day of the week has underlying patterns regarding flight count. Now, it is difficult to explain all of these trends, but if one wished to garner an even deeper understanding of why, for example, Thursdays and Fridays in November in 2007 had higher travel counts they could look at when major holidays fell in that particular month. As many people know, Thanksgiving in the US is always on a Thursday and is a big travel holiday. In 1988 Tuesday and Wednesday had the highest rate of travel in November, so maybe travel tendencies in Pittsburgh have changed or perhaps either 1988 or 2007 was an abnormality for November. It is hard to draw real conclusions without more yearly data, but general observations like these can be drawn for many of the Months/Day of the Week combinations.

# %% [markdown]
# #### 3. Flight Delays by Day of the Week in Pittsburgh in November of 2007

# %% [markdown]
# Now, to continue with the overall theme of this flight data analysis (regarding the analyst's birthday), we are going to combine the flight delay exploration and the month exploration and look specifically in November 2007.

# %%
#Create a smaller df of just flights with delays that took place in November
november_07 = delays_07.query("Month == 11")
base_color=sns.color_palette()[6]

fig, ax = plt.subplots(figsize=(16,8))
plt.suptitle('The Total Delay Time for Flights in November 2007 Group by Day of the Week')
plt.tight_layout

sns.violinplot(data=november_07, x = 'DayOfWeek', y='total_delay', ax=ax, color=base_color, inner='quartile')
ax.set_xticklabels(labels=days_of_week)
ax.set_xlabel('Day of the Week', fontsize='large')
ax.set_ylabel('Total Delay (minutes)', fontsize='large');

# %% [markdown]
# It can very quickly been seen that Monday had the largest amount of total delay time in November of 2007. Also, most days of the week dealt with delay times ranging from around 25 minutes to 65 minutes.
#
# However, there are a few more aspects of these bivariate figures which could be further explored. For instance, what type of delay combinations were most responsible for delays each day of the week experienced in 2007? Hopefully this question, and maybe more, will be answered in the following Multivariate Exploration.

# %% [markdown]
# ### Multivariate Exploration <a name="multivariate_exploration"></a>

# %% [markdown]
# #### 1. Average Total Delay Time for the Top 5 Delay Types divided by Day of the Week

# %%
#First, identify the top 5 delaytype combinations
delays_07.DelayType.value_counts().head()
# Out:
# NAS                   5566
# Carrier               3525
# Carrier, NAS          3328
# NAS, Late Aircraft    3319
# Late Aircraft         2956
# Name: DelayType, dtype: int64

# %%
#Second, create a sub dataframe including just these 5 types
top_delays = delays_07.query("DelayType == 'NAS' or DelayType == 'Carrier' or DelayType == 'Carrier, NAS' or DelayType =='NAS, Late Aircraft' or DelayType == 'Late Aircraft'")
top_delays.head()
# Out:
#       Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 2739  2007      1           2          2  22:02:00   21:20:00  23:01:00
# 4733  2007      1           3          3  15:03:00   14:35:00  21:57:00
# 5749  2007      1           3          3  18:15:00   18:10:00  19:43:00
# 5982  2007      1           3          3  07:17:00   07:15:00  08:18:00
# 9229  2007      1           4          4  17:04:00   17:05:00  19:20:00
#
#      CRSArrTime UniqueCarrier  FlightNum  ... Cancelled  CancellationCode  \
# 2739   22:35:00            WN        647  ...         0               NaN
# 4733   21:40:00            WN       2659  ...         0               NaN
# 5749   19:25:00            WN       1597  ...         0               NaN
# 5982   07:50:00            WN        571  ...         0               NaN
# 9229   19:00:00            WN        641  ...         0               NaN
#
#       Diverted  CarrierDelay  WeatherDelay  NASDelay SecurityDelay  \
# ...

# %%
#Confirm that it work with a value_counts()
top_delays.DelayType.value_counts()
# Out:
# NAS                   5566
# Carrier               3525
# Carrier, NAS          3328
# NAS, Late Aircraft    3319
# Late Aircraft         2956
# Name: DelayType, dtype: int64

# %%
#Now, use this new df to create a multivariate figure
fig, ax = plt.subplots(figsize=(12, 6))
fig.suptitle('The Average Total Delay Time of Flights for the Top 5 Delay Type Combinations, Broken Down by Day of the Week (2007)')

cat_means = top_delays.groupby(['DayOfWeek', 'DelayType']).mean()['total_delay']
cat_means = cat_means.reset_index(name = 'total_delay_avg')
cat_means = cat_means.pivot(index = 'DelayType', columns = 'DayOfWeek', values = 'total_delay_avg')

y_labels = ['Carrier', 'Carrier, NAS', 'Late Aircraft', 'NAS', 'NAS, Late Aircraft' ]

sns.heatmap(cat_means, annot = True, fmt = '.3f', annot_kws={'size':12}, cbar_kws = {'label': 'Average of Total Delay Time (minutes)'}, cmap='mako')
ax.set_yticklabels(y_labels, rotation=25)
ax.set_xticklabels(days_of_week)
ax.set_xlabel('Day of the Week', fontsize='large')
ax.set_ylabel('Delay Type Combation', fontsize='large');

# %% [markdown]
# Thanks to the colorbar it is very easy to immediately identify that NAS delays (of these top 5 delay types) had the smallest average delay for every day of the week. However, the combination of a Late Aircraft and an NAS delay resulted in the highest average total delay time for every day of the week. Earlier the bivariate analysis already indicated that the combination of Late Aircraft with other delay types resulted in higher total delay time and that pattern holds true, even when the data is additionally grouped by day of the week.

# %% [markdown]
# Now, let's use the November 07 dataframe created for the 3rd bivariate figure and see what its heatmap looks like compared to the rest of 2007.

# %%
#First confirm the top 5 delay type combinations for the november only DF
november_07.DelayType.value_counts().head()
# Out:
# NAS                       404
# Carrier                   236
# Carrier, NAS              194
# Late Aircraft             180
# Carrier, Late Aircraft    179
# Name: DelayType, dtype: int64

# %% [markdown]
# The top 5 delays are slightly different for November as compared to the rest of the year, so for consistency sake we will first plot a heatmap based on the top delay types for the year and then just for November.

# %%
#Second, create a sub dataframe using 2007 top delay types
nov_delays_07 = november_07.query("DelayType == 'NAS' or DelayType == 'Carrier' or DelayType == 'Carrier, NAS' or DelayType =='NAS, Late Aircraft' or DelayType == 'Late Aircraft'")
nov_delays_07.head()
# Out:
#          Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 6234009  2007     11           2          5  18:10:00   17:00:00  19:26:00
# 6236816  2007     11           3          6  07:39:00   07:30:00  08:54:00
# 6236826  2007     11           3          6  06:20:00   06:20:00  07:12:00
# 6242608  2007     11           5          1  08:05:00   07:30:00  10:06:00
# 6243305  2007     11           5          1  07:10:00   07:10:00  08:23:00
#
#         CRSArrTime UniqueCarrier  FlightNum  ... Cancelled  CancellationCode  \
# 6234009   18:30:00            WN       2216  ...         0               NaN
# 6236816   08:20:00            WN       2029  ...         0               NaN
# 6236826   06:45:00            WN       2527  ...         0               NaN
# 6242608   09:50:00            WN       1414  ...         0               NaN
# 6243305   08:05:00            WN        726  ...         0               NaN
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))
fig.suptitle('The Average Total Delay Time of Flights for the Top 5 Delay Type Combinations(2007), Broken Down by Day of the Week (November - 2007)')

cat_means = nov_delays_07.groupby(['DayOfWeek', 'DelayType']).mean()['total_delay']
cat_means = cat_means.reset_index(name = 'total_delay_avg')
cat_means = cat_means.pivot(index = 'DelayType', columns = 'DayOfWeek', values = 'total_delay_avg')

y_labels = ['Carrier', 'Carrier, NAS', 'Late Aircraft', 'NAS', 'NAS, Late Aircraft' ]

sns.heatmap(cat_means, annot = True, fmt = '.3f', annot_kws={'size':12}, cbar_kws = {'label': 'Average of Total Delay Time (minutes)'}, cmap='mako')
ax.set_yticklabels(y_labels, rotation=25)
ax.set_xticklabels(days_of_week)
ax.set_xlabel('Day of the Week', fontsize='large')
ax.set_ylabel('Delay Type Combation', fontsize='large');

# %% [markdown]
# The same color palette is used for this first chart as the same delay type combinations were utilized when examining the November only dataframe. As you can see, there is less consistency in the data than the overall 2007 delays dataframe. Late Aircraft and NAS/Late Aircraft delays are both top, but they rotate the number one spot depending upon the day of the week, when previously the NAS/Late Aircraft delay type took the top for every day. Additionally, NAS is still consistently low, but it no longer can claim the lowest average delay time for these delay type combinations.

# %% [markdown]
# Now, lets look at November with its actual top 5 delay type combinations, as opposed to using those from the overall 2007 delay dataframe.

# %%
#Create a df using November's top delay type combinations
nov_delays = november_07.query("DelayType == 'NAS' or DelayType == 'Carrier' or DelayType == 'Carrier, NAS' or DelayType =='Late Aircraft' or DelayType == 'Carrier, Late Aircraft'")
nov_delays.head()
# Out:
#          Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 6234009  2007     11           2          5  18:10:00   17:00:00  19:26:00
# 6236816  2007     11           3          6  07:39:00   07:30:00  08:54:00
# 6236826  2007     11           3          6  06:20:00   06:20:00  07:12:00
# 6242004  2007     11           5          1  18:44:00   17:45:00  01:30:00
# 6242608  2007     11           5          1  08:05:00   07:30:00  10:06:00
#
#         CRSArrTime UniqueCarrier  FlightNum  ... Cancelled  CancellationCode  \
# 6234009   18:30:00            WN       2216  ...         0               NaN
# 6236816   08:20:00            WN       2029  ...         0               NaN
# 6236826   06:45:00            WN       2527  ...         0               NaN
# 6242004   00:50:00            WN        512  ...         0               NaN
# 6242608   09:50:00            WN       1414  ...         0               NaN
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))
fig.suptitle('The Average Total Delay Time of Flights for the Top 5 Delay Type Combinations(Nov-07), Broken Down by Day of the Week (November - 2007)')

cat_means = nov_delays.groupby(['DayOfWeek', 'DelayType']).mean()['total_delay']
cat_means = cat_means.reset_index(name = 'total_delay_avg')
cat_means = cat_means.pivot(index = 'DelayType', columns = 'DayOfWeek', values = 'total_delay_avg')

y_labels = ['Carrier', 'Carrier, Late Aircraft', 'Carrier, NAS', 'Late Aircraft', 'NAS']

sns.heatmap(cat_means, annot = True, fmt = '.3f', annot_kws={'size':12}, cbar_kws = {'label': 'Average of Total Delay Time (minutes)'}, cmap='viridis')
ax.set_yticklabels(y_labels, rotation=25)
ax.set_xticklabels(days_of_week)
ax.set_xlabel('Day of the Week', fontsize='large')
ax.set_ylabel('Delay Type Combation', fontsize='large');

# %% [markdown]
# Similar to the above heat maps, but still very  much its own. A different color pallet was used to further differentiate between the two top 5 delay type choices (2007 vs Nov-07). It can be easily seen, with the bright yellow, that the November dataframe shows an increased emphasis on the 'Carrier, Late Aircraft' delay type, which was not featured in the overall 2007 delays top 5 delay types. In fact, this combination features the 2nd and 3rd highest average total delay times for all three heatmaps, despite this category not making it to the top 5 of the overall 2007 delay dataframe. However, it needs to be noted that the second most prominent delay type is again the stand-alone Late Aircraft type which was also very consistently 1st or 2nd in the previous figures as well.

# %% [markdown]
# #### 2. Destinations on November 20th 2007, Delay Types, and the Total Elapsed Time

# %% [markdown]
# To conclude the analysis, it is only fitting that flight data on my 18th birthday in 2007 is examined. The last figure will examine the total elapsed flight time for all flights which departed Pittsburgh with delays on November 20th, 2007.

# %%
#Create November 20, 2007 df

nov_20_07 = delays_07.query("Month == 11 & DayofMonth == 20 & Dest != 'PIT'")
nov_20_07.head()
# Out:
#          Year  Month  DayofMonth  DayOfWeek   DepTime CRSDepTime   ArrTime  \
# 6293193  2007     11          20          2  14:13:00   14:10:00  14:57:00
# 6293194  2007     11          20          2  13:14:00   12:05:00  14:30:00
# 6293195  2007     11          20          2  21:09:00   20:35:00  21:25:00
# 6293197  2007     11          20          2  17:20:00   14:55:00  18:23:00
# 6293198  2007     11          20          2  20:29:00   18:15:00  21:46:00
#
#         CRSArrTime UniqueCarrier  FlightNum  ... Cancelled  CancellationCode  \
# 6293193   14:35:00            WN        921  ...         0               NaN
# 6293194   12:35:00            WN       2361  ...         0               NaN
# 6293195   21:05:00            WN       3336  ...         0               NaN
# 6293197   16:10:00            WN        374  ...         0               NaN
# 6293198   19:50:00            WN        548  ...         0               NaN
#
# ...

# %%
nov_20_07.Dest.value_counts()
# Out:
# PHL    10
# ORD     6
# JFK     4
# EWR     4
# MDW     3
# DFW     3
# LGA     2
# DEN     1
# MEM     1
# DCA     1
# BOS     1
# IAD     1
# Name: Dest, dtype: int64

# %%
nov_20_07.DelayType.value_counts()
# Out:
# NAS                            13
# NAS, Late Aircraft             12
# Late Aircraft                   6
# Carrier, Late Aircraft          2
# Carrier                         2
# Carrier, NAS, Late Aircraft     1
# Weather, Late Aircraft          1
# Name: DelayType, dtype: int64

# %% [markdown]
# On November 20th, 2007 only 37 total flights left Pittsburgh and experienced delays. This  is a small enough number that no additional wrangling of this sub-dataframe is required to efficiently display the desired data.

# %%
fig, ax = plt.subplots(figsize=(16, 8))
fig.suptitle('The Total Elapsed Time for Flights Departing Pittsburgh on November 20th, 2007', fontsize = 16)

dest_order = ['PHL', 'ORD', 'EWR', 'JFK', 'MDW', 'DFW', 'LGA', 'MEM', 'BOS', 'DEN', 'IAD', 'DCA']

sns.pointplot(data=nov_20_07, x = 'Dest', y = 'ActualElapsedTime', order = dest_order, hue = 'DelayType', dodge = .3, linestyles = "")
ax.legend(title='Delay Types')
ax.set_xlabel('Destinations', fontsize=12)
ax.set_ylabel('Total Elapsed Time (minutes)', fontsize=12);

# %% [markdown]
# As mentioned above, this final figure only features 37 data points. So, that makes the analysis of this particular figure extremely limited, but it did capture the desired information efficiently. Performing this same type of analysis on a larger portion or the whole dataframe would have required the limiting of destinations and delay types, as this type of figure would have been overwhelmed with data points quickly.
#
# What this figure can tell us is that NAS delays were the most frequent(noted by the number of blue data points), followed by the NAS/Late Aircraft combination(orange data points). Additionally, Philadelphia was the top Destination. It also shows that the lone flight to Denver was the longest flight of the 37 which departed Pittsburgh on November 20th. This is likely due to both its distance (relative to other airpots) and the NAS/Late Aircraft delay it experienced.

# %% [markdown]
# ### Project Conclusions and Results <a name="project_conclusions"></a>

# %% [markdown]
# This Exploratory Analysis's goal was to examine flight data related to Pittsburgh, PA in 1988 and 2007, this Analyst's birth year and last year in Pittsburgh. As I mentioned in the introduction, I felt it was fitting, given the timing of this class ending a week before my 32nd birthday, to focus the analysis around aspects of my own life. It gave a wonderful limiting factor on the overwhelming amount of flight data which was available for analysis and also provided great direction for bivariate and multivariate plots of the flight data from 1988 and 2007.
#
# The key takeaways from this exploratory analysis are the following (in no particular order):
# <ul>
#     <li>There were substantially more flights (over 2x more) in 1988 in Pittsburgh than in 2007</li>
#     <li>Despite the vast difference in numbers, the overall pattern remaind fairly consistent when looking at flight data by month or by day of the week</li>
#     <li>Summer travel was preferred over the Winter months and February was the least preferred month to travel</li>
#     <li>Weekdays were preferred for travel over weekends and Saturday was the least favorite day for a flight</li>
#     <li>Late Aircraft delays caused many delays for flights in and out of Pittsburgh in 2007</li>
#     <li>No day of the week saw a lot more total delay time when for the top 5 delay types, but unsurprisingly, weekdays experienced more total delay time than weekends - likely due to the increased travel</li>
# </ul>
#
# It is also very important to note that this visual exploration of the data is very limited. While the numbers are sound and presented with transparent methodology, they do not remotely begin to capture all of the internal and external factors which influence individual flights or the overall annual flight data. For instance, September 11th, 2001 greatly affected the airline industry in the US. This could be one of the underlying factors for the overall decrease in flights from 1988 to 2007 in Pittsburgh.
#
# Additionally, this analysis only examines 2 years worth of data and the data is 20 years apart. Therefore it is impossible to say that 1988 or 2007 were not outliers when compared to the other 18 years worth of data in between the two time periods. It is also possible that technological advancements drastically changed airport and flight behaviors making the data less comparable than basic analysis would indicate.
#
# Suffice to say, while this data did provide some interesting insights, they are very focused results based around this Analyst's particular interests and do not adequately represent enough data to comment on any significant trends in aviation data. The visual exploration efficiently captured the desired analysis, but is not a replacement for a holistic analysis of all the flight data for the entire period from 1988 to 2007.

# %% [markdown]
# <em>Throughout this analysis, credit was given to any significant reference utilized for the creation of this project. Additionally, Udacity resources related to Data Analyst Nanodegree were referenced, along with minimal review of similar problems in the Mentor Resources. No aspects of this project were knowingly plagarized.</em>
